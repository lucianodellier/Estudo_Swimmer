# %%
import numpy as np
import pandas as pd
import os
import copy
import matplotlib.pylab as plt
import scipy.signal

# %%
nballs = 4 # 4,5,6,10
ang = 45
expcase = 6

if nballs == 4:
    if ang == 5:
        if expcase == 1: #100 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta5/evolqlquantities_pandas_100steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta5/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 2: #1000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta5/evolqlquantities_pandas_1000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta5/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 3: #5000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta5/evolqlquantities_pandas_5000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta5/deltas.txt -O deltas.txt &> /dev/null   
        elif expcase == 4: #10000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta5/evolqlquantities_pandas_10000steps.txt -O evolqlquantities.txt &> /dev/null        
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta5/deltas.txt -O deltas.txt &> /dev/null 
        elif expcase == 5: #50000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta5/evolqlquantities_pandas_50000steps.txt -O evolqlquantities.txt &> /dev/null  
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta5/deltas.txt -O deltas.txt &> /dev/null        
        elif expcase == 6: #100000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta5/evolqlquantities_pandas_100000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta5/deltas.txt -O deltas.txt &> /dev/null 
    elif ang == 10:
        if expcase == 1: #100 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta10/evolqlquantities_pandas_100steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta10/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 2: #1000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta10/evolqlquantities_pandas_1000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta10/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 3: #5000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta10/evolqlquantities_pandas_5000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta10/deltas.txt -O deltas.txt &> /dev/null   
        elif expcase == 4: #10000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta10/evolqlquantities_pandas_10000steps.txt -O evolqlquantities.txt &> /dev/null        
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta10/deltas.txt -O deltas.txt &> /dev/null 
        elif expcase == 5: #50000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta10/evolqlquantities_pandas_50000steps.txt -O evolqlquantities.txt &> /dev/null  
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta10/deltas.txt -O deltas.txt &> /dev/null        
        elif expcase == 6: #100000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta10/evolqlquantities_pandas_100000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta10/deltas.txt -O deltas.txt &> /dev/null
    elif ang == 15:
        if expcase == 1: #100 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta15/evolqlquantities_pandas_100steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta15/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 2: #1000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta15/evolqlquantities_pandas_1000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta15/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 3: #5000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta15/evolqlquantities_pandas_5000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta15/deltas.txt -O deltas.txt &> /dev/null   
        elif expcase == 4: #10000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta15/evolqlquantities_pandas_10000steps.txt -O evolqlquantities.txt &> /dev/null        
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta15/deltas.txt -O deltas.txt &> /dev/null 
        elif expcase == 5: #50000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta15/evolqlquantities_pandas_50000steps.txt -O evolqlquantities.txt &> /dev/null  
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta15/deltas.txt -O deltas.txt &> /dev/null        
        elif expcase == 6: #100000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta15/evolqlquantities_pandas_100000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta15/deltas.txt -O deltas.txt &> /dev/null                  
    elif ang == 20:
        if expcase == 1: #100 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta20/evolqlquantities_pandas_100steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta20/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 2: #1000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta20/evolqlquantities_pandas_1000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta20/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 3: #5000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta20/evolqlquantities_pandas_5000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta20/deltas.txt -O deltas.txt &> /dev/null   
        elif expcase == 4: #10000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta20/evolqlquantities_pandas_10000steps.txt -O evolqlquantities.txt &> /dev/null        
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta20/deltas.txt -O deltas.txt &> /dev/null 
        elif expcase == 5: #50000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta20/evolqlquantities_pandas_50000steps.txt -O evolqlquantities.txt &> /dev/null  
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta20/deltas.txt -O deltas.txt &> /dev/null        
        elif expcase == 6: #100000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta20/evolqlquantities_pandas_100000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta20/deltas.txt -O deltas.txt &> /dev/null                         
    elif ang == 25:
        if expcase == 1: #100 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta25/evolqlquantities_pandas_100steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta25/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 2: #1000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta25/evolqlquantities_pandas_1000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta25/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 3: #5000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta25/evolqlquantities_pandas_5000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta25/deltas.txt -O deltas.txt &> /dev/null   
        elif expcase == 4: #10000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta25/evolqlquantities_pandas_10000steps.txt -O evolqlquantities.txt &> /dev/null        
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta25/deltas.txt -O deltas.txt &> /dev/null 
        elif expcase == 5: #50000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta25/evolqlquantities_pandas_50000steps.txt -O evolqlquantities.txt &> /dev/null  
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta25/deltas.txt -O deltas.txt &> /dev/null        
        elif expcase == 6: #100000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta25/evolqlquantities_pandas_100000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta25/deltas.txt -O deltas.txt &> /dev/null                  
    elif ang == 30:
        if expcase == 1: #100 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta30/evolqlquantities_pandas_100steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta30/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 2: #1000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta30/evolqlquantities_pandas_1000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta30/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 3: #5000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta30/evolqlquantities_pandas_5000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta30/deltas.txt -O deltas.txt &> /dev/null   
        elif expcase == 4: #10000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta30/evolqlquantities_pandas_10000steps.txt -O evolqlquantities.txt &> /dev/null        
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta30/deltas.txt -O deltas.txt &> /dev/null 
        elif expcase == 5: #50000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta30/evolqlquantities_pandas_50000steps.txt -O evolqlquantities.txt &> /dev/null  
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta30/deltas.txt -O deltas.txt &> /dev/null        
        elif expcase == 6: #100000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta30/evolqlquantities_pandas_100000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta30/deltas.txt -O deltas.txt &> /dev/null                    
    elif ang == 35:
        if expcase == 1: #100 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta35/evolqlquantities_pandas_100steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta35/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 2: #1000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta35/evolqlquantities_pandas_1000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta35/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 3: #5000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta35/evolqlquantities_pandas_5000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta35/deltas.txt -O deltas.txt &> /dev/null   
        elif expcase == 4: #10000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta35/evolqlquantities_pandas_10000steps.txt -O evolqlquantities.txt &> /dev/null        
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta35/deltas.txt -O deltas.txt &> /dev/null 
        elif expcase == 5: #50000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta35/evolqlquantities_pandas_50000steps.txt -O evolqlquantities.txt &> /dev/null  
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta35/deltas.txt -O deltas.txt &> /dev/null        
        elif expcase == 6: #100000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta35/evolqlquantities_pandas_100000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta35/deltas.txt -O deltas.txt &> /dev/null                   
    elif ang == 40:
        if expcase == 1: #100 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta40/evolqlquantities_pandas_100steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta40/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 2: #1000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta40/evolqlquantities_pandas_1000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta40/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 3: #5000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta40/evolqlquantities_pandas_5000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta40/deltas.txt -O deltas.txt &> /dev/null   
        elif expcase == 4: #10000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta40/evolqlquantities_pandas_10000steps.txt -O evolqlquantities.txt &> /dev/null        
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta40/deltas.txt -O deltas.txt &> /dev/null 
        elif expcase == 5: #50000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta40/evolqlquantities_pandas_50000steps.txt -O evolqlquantities.txt &> /dev/null  
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta40/deltas.txt -O deltas.txt &> /dev/null        
        elif expcase == 6: #100000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta40/evolqlquantities_pandas_100000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta40/deltas.txt -O deltas.txt &> /dev/null                      
    elif ang == 45:
        if expcase == 1: #100 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta45/evolqlquantities_pandas_100steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta45/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 2: #1000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta45/evolqlquantities_pandas_1000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta45/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 3: #5000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta45/evolqlquantities_pandas_5000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta45/deltas.txt -O deltas.txt &> /dev/null   
        elif expcase == 4: #10000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta45/evolqlquantities_pandas_10000steps.txt -O evolqlquantities.txt &> /dev/null        
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta45/deltas.txt -O deltas.txt &> /dev/null 
        elif expcase == 5: #50000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta45/evolqlquantities_pandas_50000steps.txt -O evolqlquantities.txt &> /dev/null  
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta45/deltas.txt -O deltas.txt &> /dev/null        
        elif expcase == 6: #100000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta45/evolqlquantities_pandas_100000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta45/deltas.txt -O deltas.txt &> /dev/null                    
    elif ang == 60:
        if expcase == 1: #100 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta60/evolqlquantities_pandas_100steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta60/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 2: #1000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta60/evolqlquantities_pandas_1000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta60/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 3: #5000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta60/evolqlquantities_pandas_5000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta60/deltas.txt -O deltas.txt &> /dev/null   
        elif expcase == 4: #10000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta60/evolqlquantities_pandas_10000steps.txt -O evolqlquantities.txt &> /dev/null        
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta60/deltas.txt -O deltas.txt &> /dev/null 
        elif expcase == 5: #50000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta60/evolqlquantities_pandas_50000steps.txt -O evolqlquantities.txt &> /dev/null  
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta60/deltas.txt -O deltas.txt &> /dev/null        
        elif expcase == 6: #100000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta60/evolqlquantities_pandas_100000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta60/deltas.txt -O deltas.txt &> /dev/null                   
    elif ang == 70:
        if expcase == 1: #100 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta70/evolqlquantities_pandas_100steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta70/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 2: #1000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta70/evolqlquantities_pandas_1000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta70/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 3: #5000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta70/evolqlquantities_pandas_5000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta70/deltas.txt -O deltas.txt &> /dev/null   
        elif expcase == 4: #10000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta70/evolqlquantities_pandas_10000steps.txt -O evolqlquantities.txt &> /dev/null        
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta70/deltas.txt -O deltas.txt &> /dev/null 
        elif expcase == 5: #50000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta70/evolqlquantities_pandas_50000steps.txt -O evolqlquantities.txt &> /dev/null  
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta70/deltas.txt -O deltas.txt &> /dev/null        
        elif expcase == 6: #100000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta70/evolqlquantities_pandas_100000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta70/deltas.txt -O deltas.txt &> /dev/null
    elif ang == 80:
        if expcase == 1: #100 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta80/evolqlquantities_pandas_100steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta80/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 2: #1000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta80/evolqlquantities_pandas_1000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta80/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 3: #5000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta80/evolqlquantities_pandas_5000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta80/deltas.txt -O deltas.txt &> /dev/null   
        elif expcase == 4: #10000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta80/evolqlquantities_pandas_10000steps.txt -O evolqlquantities.txt &> /dev/null        
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta80/deltas.txt -O deltas.txt &> /dev/null 
        elif expcase == 5: #50000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta80/evolqlquantities_pandas_50000steps.txt -O evolqlquantities.txt &> /dev/null  
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta80/deltas.txt -O deltas.txt &> /dev/null        
        elif expcase == 6: #100000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta80/evolqlquantities_pandas_100000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta80/deltas.txt -O deltas.txt &> /dev/null
    elif ang == 90:
        if expcase == 1: #100 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta90/evolqlquantities_pandas_100steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta90/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 2: #1000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta90/evolqlquantities_pandas_1000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta90/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 3: #5000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta90/evolqlquantities_pandas_5000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta90/deltas.txt -O deltas.txt &> /dev/null   
        elif expcase == 4: #10000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta90/evolqlquantities_pandas_10000steps.txt -O evolqlquantities.txt &> /dev/null        
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta90/deltas.txt -O deltas.txt &> /dev/null 
        elif expcase == 5: #50000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta90/evolqlquantities_pandas_50000steps.txt -O evolqlquantities.txt &> /dev/null  
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta90/deltas.txt -O deltas.txt &> /dev/null        
        elif expcase == 6: #100000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/4bodies/theta90/evolqlquantities_pandas_100000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/4bodies-Deltas/theta90/deltas.txt -O deltas.txt &> /dev/null                                                    

elif nballs == 5:
    if ang == 5:
        if expcase == 1: #100 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta5/evolqlquantities_pandas_100steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/5graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 2: #1000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta5/evolqlquantities_pandas_1000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/5graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 3: #5000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta5/evolqlquantities_pandas_5000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/5graus/deltas.txt -O deltas.txt &> /dev/null   
        elif expcase == 4: #10000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta5/evolqlquantities_pandas_10000steps.txt -O evolqlquantities.txt &> /dev/null        
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/5graus/deltas.txt -O deltas.txt &> /dev/null 
        elif expcase == 5: #50000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta5/evolqlquantities_pandas_50000steps.txt -O evolqlquantities.txt &> /dev/null  
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/5graus/deltas.txt -O deltas.txt &> /dev/null        
        elif expcase == 6: #100000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta5/evolqlquantities_pandas_100000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/5graus/deltas.txt -O deltas.txt &> /dev/null 
    elif ang == 10:
        if expcase == 1: #100 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta10/evolqlquantities_pandas_100steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/10graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 2: #1000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta10/evolqlquantities_pandas_1000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/10graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 3: #5000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta10/evolqlquantities_pandas_5000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/10graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 4: #10000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta10/evolqlquantities_pandas_10000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/10graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 5: #50000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta10/evolqlquantities_pandas_50000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/10graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 6: #100000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta10/evolqlquantities_pandas_100000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/10graus/deltas.txt -O deltas.txt &> /dev/null
    elif ang == 15:
        if expcase == 1: #100 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta15/evolqlquantities_pandas_100steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/15graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 2: #1000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta15/evolqlquantities_pandas_1000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/15graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 3: #5000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta15/evolqlquantities_pandas_5000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/15graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 4: #10000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta15/evolqlquantities_pandas_10000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/15graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 5: #50000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta15/evolqlquantities_pandas_50000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/15graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 6: #100000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta15/evolqlquantities_pandas_100000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/15graus/deltas.txt -O deltas.txt &> /dev/null
    elif ang == 20:
        if expcase == 1: #100 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta20/evolqlquantities_pandas_100steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/20graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 2: #1000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta20/evolqlquantities_pandas_1000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/20graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 3: #5000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta20/evolqlquantities_pandas_5000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/20graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 4: #10000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta20/evolqlquantities_pandas_10000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/20graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 5: #50000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta20/evolqlquantities_pandas_50000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/20graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 6: #100000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta20/evolqlquantities_pandas_100000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/20graus/deltas.txt -O deltas.txt &> /dev/null
    elif ang == 25:
        if expcase == 1: #100 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta25/evolqlquantities_pandas_100steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/25graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 2: #1000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta25/evolqlquantities_pandas_1000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/25graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 3: #5000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta25/evolqlquantities_pandas_5000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/25graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 4: #10000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta25/evolqlquantities_pandas_10000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/25graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 5: #50000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta25/evolqlquantities_pandas_50000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/25graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 6: #100000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta25/evolqlquantities_pandas_100000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/25graus/deltas.txt -O deltas.txt &> /dev/null
    elif ang == 30:
        if expcase == 1: #100 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta30/evolqlquantities_pandas_100steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/30graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 2: #1000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta30/evolqlquantities_pandas_1000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/30graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 3: #5000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta30/evolqlquantities_pandas_5000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/30graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 4: #10000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta30/evolqlquantities_pandas_10000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/30graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 5: #50000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta30/evolqlquantities_pandas_50000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/30graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 6: #100000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta30/evolqlquantities_pandas_100000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/30graus/deltas.txt -O deltas.txt &> /dev/null
    elif ang == 35:
        if expcase == 1: #100 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta35/evolqlquantities_pandas_100steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/35graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 2: #1000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta35/evolqlquantities_pandas_1000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/35graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 3: #5000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta35/evolqlquantities_pandas_5000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/35graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 4: #10000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta35/evolqlquantities_pandas_10000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/35graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 5: #50000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta35/evolqlquantities_pandas_50000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/35graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 6: #100000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta35/evolqlquantities_pandas_100000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/35graus/deltas.txt -O deltas.txt &> /dev/null
    elif ang == 40:
        if expcase == 1: #100 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta40/evolqlquantities_pandas_100steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/40graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 2: #1000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta40/evolqlquantities_pandas_1000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/40graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 3: #5000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta40/evolqlquantities_pandas_5000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/40graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 4: #10000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta40/evolqlquantities_pandas_10000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/40graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 5: #50000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta40/evolqlquantities_pandas_50000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/40graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 6: #100000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta40/evolqlquantities_pandas_100000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/40graus/deltas.txt -O deltas.txt &> /dev/null
    elif ang == 45:
        if expcase == 1: #100 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta45/evolqlquantities_pandas_100steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/45graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 2: #1000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta45/evolqlquantities_pandas_1000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/45graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 3: #5000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta45/evolqlquantities_pandas_5000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/45graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 4: #10000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta45/evolqlquantities_pandas_10000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/45graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 5: #50000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta45/evolqlquantities_pandas_50000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/45graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 6: #100000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta45/evolqlquantities_pandas_100000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/45graus/deltas.txt -O deltas.txt &> /dev/null
    elif ang == 50:
        if expcase == 1: #100 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta50/evolqlquantities_pandas_100steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/50graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 2: #1000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta50/evolqlquantities_pandas_1000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/50graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 3: #5000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta50/evolqlquantities_pandas_5000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/50graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 4: #10000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta50/evolqlquantities_pandas_10000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/50graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 5: #50000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta50/evolqlquantities_pandas_50000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/50graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 6: #100000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/5bodies/theta50/evolqlquantities_pandas_100000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/5bodies/50graus/deltas.txt -O deltas.txt &> /dev/null

elif nballs == 6:
    if ang == 5:
        if expcase == 1: #100 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta5/evolqlquantities_pandas_100steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/5graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 2: #1000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta5/evolqlquantities_pandas_1000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/5graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 3: #5000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta5/evolqlquantities_pandas_5000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/5graus/deltas.txt -O deltas.txt &> /dev/null   
        elif expcase == 4: #10000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta5/evolqlquantities_pandas_10000steps.txt -O evolqlquantities.txt &> /dev/null        
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/5graus/deltas.txt -O deltas.txt &> /dev/null 
        elif expcase == 5: #50000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta5/evolqlquantities_pandas_50000steps.txt -O evolqlquantities.txt &> /dev/null  
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/5graus/deltas.txt -O deltas.txt &> /dev/null        
        elif expcase == 6: #100000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta5/evolqlquantities_pandas_100000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/5graus/deltas.txt -O deltas.txt &> /dev/null 
    elif ang == 10:
        if expcase == 1: #100 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta10/evolqlquantities_pandas_100steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/10graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 2: #1000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta10/evolqlquantities_pandas_1000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/10graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 3: #5000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta10/evolqlquantities_pandas_5000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/10graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 4: #10000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta10/evolqlquantities_pandas_10000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/10graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 5: #50000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta10/evolqlquantities_pandas_50000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/10graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 6: #100000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta10/evolqlquantities_pandas_100000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/10graus/deltas.txt -O deltas.txt &> /dev/null
    elif ang == 15:
        if expcase == 1: #100 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta15/evolqlquantities_pandas_100steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/15graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 2: #1000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta15/evolqlquantities_pandas_1000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/15graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 3: #5000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta15/evolqlquantities_pandas_5000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/15graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 4: #10000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta15/evolqlquantities_pandas_10000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/15graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 5: #50000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta15/evolqlquantities_pandas_50000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/15graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 6: #100000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta15/evolqlquantities_pandas_100000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/15graus/deltas.txt -O deltas.txt &> /dev/null
    elif ang == 20:
        if expcase == 1: #100 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta20/evolqlquantities_pandas_100steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/20graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 2: #1000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta20/evolqlquantities_pandas_1000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/20graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 3: #5000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta20/evolqlquantities_pandas_5000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/20graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 4: #10000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta20/evolqlquantities_pandas_10000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/20graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 5: #50000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta20/evolqlquantities_pandas_50000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/20graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 6: #100000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta20/evolqlquantities_pandas_100000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/20graus/deltas.txt -O deltas.txt &> /dev/null
    elif ang == 25:
        if expcase == 1: #100 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta25/evolqlquantities_pandas_100steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/25graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 2: #1000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta25/evolqlquantities_pandas_1000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/25graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 3: #5000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta25/evolqlquantities_pandas_5000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/25graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 4: #10000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta25/evolqlquantities_pandas_10000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/25graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 5: #50000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta25/evolqlquantities_pandas_50000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/25graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 6: #100000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta25/evolqlquantities_pandas_100000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/25graus/deltas.txt -O deltas.txt &> /dev/null
    elif ang == 30:
        if expcase == 1: #100 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta30/evolqlquantities_pandas_100steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/30graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 2: #1000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta30/evolqlquantities_pandas_1000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/30graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 3: #5000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta30/evolqlquantities_pandas_5000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/30graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 4: #10000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta30/evolqlquantities_pandas_10000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/30graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 5: #50000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta30/evolqlquantities_pandas_50000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/30graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 6: #100000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta30/evolqlquantities_pandas_100000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/30graus/deltas.txt -O deltas.txt &> /dev/null
    elif ang == 35:
        if expcase == 1: #100 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta35/evolqlquantities_pandas_100steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/35graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 2: #1000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta35/evolqlquantities_pandas_1000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/35graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 3: #5000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta35/evolqlquantities_pandas_5000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/35graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 4: #10000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta35/evolqlquantities_pandas_10000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/35graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 5: #50000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta35/evolqlquantities_pandas_50000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/35graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 6: #100000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta35/evolqlquantities_pandas_100000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/35graus/deltas.txt -O deltas.txt &> /dev/null
    elif ang == 40:
        if expcase == 1: #100 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta40/evolqlquantities_pandas_100steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/40graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 2: #1000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta40/evolqlquantities_pandas_1000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/40graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 3: #5000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta40/evolqlquantities_pandas_5000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/40graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 4: #10000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta40/evolqlquantities_pandas_10000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/40graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 5: #50000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta40/evolqlquantities_pandas_50000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/40graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 6: #100000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta40/evolqlquantities_pandas_100000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/40graus/deltas.txt -O deltas.txt &> /dev/null
    elif ang == 45:
        if expcase == 1: #100 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta45/evolqlquantities_pandas_100steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/45graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 2: #1000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta45/evolqlquantities_pandas_1000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/45graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 3: #5000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta45/evolqlquantities_pandas_5000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/45graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 4: #10000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta45/evolqlquantities_pandas_10000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/45graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 5: #50000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta45/evolqlquantities_pandas_50000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/45graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 6: #100000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta45/evolqlquantities_pandas_100000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/45graus/deltas.txt -O deltas.txt &> /dev/null
    elif ang == 50:
        if expcase == 1: #100 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta50/evolqlquantities_pandas_100steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/50graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 2: #1000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta50/evolqlquantities_pandas_1000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/50graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 3: #5000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta50/evolqlquantities_pandas_5000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/50graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 4: #10000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta50/evolqlquantities_pandas_10000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/50graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 5: #50000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta50/evolqlquantities_pandas_50000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/50graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 6: #100000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/6bodies/theta50/evolqlquantities_pandas_100000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/6bodies/50graus/deltas.txt -O deltas.txt &> /dev/null 

elif nballs == 10:
    if ang == 15:
        if expcase == 1: #100 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/10bodies/theta15/evolqlquantities_pandas_100steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/10bodies/15graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 2: #1000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/10bodies/theta15/evolqlquantities_pandas_1000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/10bodies/15graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 3: #5000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/10bodies/theta15/evolqlquantities_pandas_5000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/10bodies/15graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 4: #10000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/10bodies/theta15/evolqlquantities_pandas_10000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/10bodies/15graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 5: #50000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/10bodies/theta15/evolqlquantities_pandas_50000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/10bodies/15graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 6: #100000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/10bodies/theta15/evolqlquantities_pandas_100000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/10bodies/15graus/deltas.txt -O deltas.txt &> /dev/null 
    elif ang == 25:
        if expcase == 1: #100 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/10bodies/theta25/evolqlquantities_pandas_100steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/10bodies/25graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 2: #1000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/10bodies/theta25/evolqlquantities_pandas_1000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/10bodies/25graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 3: #5000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/10bodies/theta25/evolqlquantities_pandas_5000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/10bodies/25graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 4: #10000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/10bodies/theta25/evolqlquantities_pandas_10000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/10bodies/25graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 5: #50000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/10bodies/theta25/evolqlquantities_pandas_50000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/10bodies/25graus/deltas.txt -O deltas.txt &> /dev/null
        elif expcase == 6: #100000 steps
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/Dados/10bodies/theta25/evolqlquantities_pandas_100000steps.txt -O evolqlquantities.txt &> /dev/null
            # !wget https://raw.githubusercontent.com/lucianodellier/Estudo_Swimmer/main/DeltasNovos/10bodies/25graus/deltas.txt -O deltas.txt &> /dev/null

# %%
dir_   = '.'
eqlfile = 'evolqlquantities.txt'
df = pd.read_csv(dir_+'/'+eqlfile, sep=",")

deltasfile = 'deltas.txt'
DELTAS = np.loadtxt(dir_+'/'+deltasfile)

# %%
##nballs = 4
nlinks = nballs-1
nstates = 2**nlinks
nactions = nlinks
ndeltas = 6

tfdata = len(df) 
nqlsteps = tfdata

data = df.to_numpy()

s_batch  = data[:tfdata,0]
a_batch  = data[:tfdata,1]
sn_batch = data[:tfdata,2]
x_batch = data[:tfdata,3]
y_batch = data[:tfdata,4]
xn_batch = data[:tfdata,5]
yn_batch = data[:tfdata,6]
theta_batch = data[:tfdata,7]
thetan_batch = data[:tfdata,8]

rcase = 1

if rcase == 1: #rotation
    r_batch = thetan_batch - theta_batch

# %%
plt.plot(theta_batch)
plt.ylabel('theta ini')
plt.xlabel('it')
plt.show()

plt.plot(x_batch,y_batch)
plt.ylabel('ycm')
plt.xlabel('xcm')
plt.show()

# %%
print(df.describe())
# Out:
#               Statei        Action         Staten           xcmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean        3.495790       0.99849       3.495820     210.810687
# std         2.293529       0.81644       2.293503      11.385755
# min         0.000000       0.00000       0.000000     195.084695
# 25%         1.000000       0.00000       1.000000     199.761095
# 50%         3.000000       1.00000       3.000000     207.096729
# 75%         6.000000       2.00000       6.000000     223.664292
# max         7.000000       2.00000       7.000000     227.889597
#
#                 ycmi           xcmn           ycmn         thetai  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean      216.516155     210.810419     216.515971      -2.048680
# std         8.698145      11.385736       8.698160       0.979563
# min       197.114185     195.084695     197.114185      -4.536266
# ...

# %%
print(df.var())
# Out:
# Statei      5.260275
# Action      0.666574
# Staten      5.260155
# xcmi      129.635415
# ycmi       75.657731
# xcmn      129.634984
# ycmn       75.657991
# thetai      0.959544
# thetan      0.959507
# dtype: float64

# %%
print(df.corr())
# Out:
#           Statei    Action    Staten      xcmi      ycmi      xcmn      ycmn  \
# Statei  1.000000 -0.000754  0.333586 -0.018998  0.014238 -0.004833  0.004682
# Action -0.000754  1.000000 -0.000748  0.001404  0.002761  0.001402  0.002769
# Staten  0.333586 -0.000748  1.000000 -0.004902  0.004829 -0.018977  0.014255
# xcmi   -0.018998  0.001404 -0.004902  1.000000  0.883754  0.999508  0.883883
# ycmi    0.014238  0.002761  0.004829  0.883754  1.000000  0.883865  0.999404
# xcmn   -0.004833  0.001402 -0.018977  0.999508  0.883865  1.000000  0.883754
# ycmn    0.004682  0.002769  0.014255  0.883883  0.999404  0.883754  1.000000
# thetai -0.740322 -0.000443 -0.247852 -0.143435 -0.334038 -0.154191 -0.326780
# thetan -0.247724 -0.000465 -0.740314 -0.154188 -0.326905 -0.143472 -0.334073
#
#           thetai    thetan
# Statei -0.740322 -0.247724
# Action -0.000443 -0.000465
# Staten -0.247852 -0.740314
# xcmi   -0.143435 -0.154188
# ycmi   -0.334038 -0.326905
# xcmn   -0.154191 -0.143472
# ...

# %%
print(df.cov())
# Out:
#           Statei    Action    Staten        xcmi       ycmi        xcmn  \
# Statei  5.260275 -0.001411  1.754735   -0.496097   0.284039   -0.126199
# Action -0.001411  0.666574 -0.001401    0.013055   0.019609    0.013035
# Staten  1.754735 -0.001401  5.260155   -0.128016   0.096342   -0.495539
# xcmi   -0.496097  0.013055 -0.128016  129.635415  87.522531  129.571442
# ycmi    0.284039  0.019609  0.096342   87.522531  75.657731   87.533338
# xcmn   -0.126199  0.013035 -0.495539  129.571442  87.533338  129.634984
# ycmn    0.093398  0.019661  0.284385   87.535494  75.612776   87.522573
# thetai -1.663248 -0.000354 -0.556832   -1.599734  -2.846134   -1.719695
# thetan -0.556540 -0.000372 -1.663180   -1.719637  -2.785304   -1.600120
#
#              ycmn    thetai    thetan
# Statei   0.093398 -1.663248 -0.556540
# Action   0.019661 -0.000354 -0.000372
# Staten   0.284385 -0.556832 -1.663180
# xcmi    87.535494 -1.599734 -1.719637
# ycmi    75.612776 -2.846134 -2.785304
# ...

# %%
def ReadDeltasTables(ndeltas, nstates, nactions, filetable):            
    
    A = filetable
    Deltas = []
    for d in range(ndeltas):
        Deltas.append(np.zeros(shape=(nstates, nactions)))
        for state in range(nstates):
            Deltas[d][state, :] = A[d * nstates + state, :]
    return Deltas  

def QL_steps_sb(s_batch,sn_batch,a_batch,r_batch,alpha,gamma,replay_step,nreplay):
  # Initilize QL matrix

  MQL  = np.zeros((nstates,nactions))
  MQLn = np.zeros((nstates,nactions))
  DMQL = []

  # QL steps
  for it in range(nqlsteps):   
    
    # Learning  #######################################################    
    prev_state_dec  = int(s_batch[it])
    next_action_dec = int(a_batch[it])
    next_state_dec  = int(sn_batch[it])    
    next_MQLmax     = np.max(MQL[next_state_dec,:])
    
    next_MQLmax_inverse     = np.max(MQL[prev_state_dec,:])
    current_MQLval  = MQL[prev_state_dec,next_action_dec]
    current_MQLval_inverse  = MQL[prev_state_dec,next_action_dec]
    current_reward  = r_batch[it]    

    MQL[prev_state_dec,next_action_dec] = (1-alpha)*current_MQLval + \
      alpha*(current_reward + gamma*next_MQLmax)

    MQL[next_state_dec,next_action_dec] = (1-alpha)*current_MQLval_inverse + \
      alpha*(-current_reward + gamma*next_MQLmax_inverse)   

    if replay_step > 0 and it%replay_step == 0:
      MQL, DMQL = replay_sb(MQL,s_batch,sn_batch,a_batch,r_batch,alpha,gamma,nreplay,DMQL)       
      ##nbatch = 50
      ##MQL, DMQL = replay_sb(MQL,s_batch[it-nbatch:it],sn_batch[it-nbatch:it],a_batch[it-nbatch:it],r_batch[it-nbatch:it],alpha,gamma,nreplay,DMQL)

    DMQL.append(np.linalg.norm(MQL-MQLn))
    MQLn = copy.deepcopy(MQL)    

  return MQL, DMQL


def replay_sb(MQL,s_batch,sn_batch,a_batch,r_batch,alpha,gamma,nreplay,DMQL):
 
   MQLC = copy.deepcopy(MQL)
   MQLn = copy.deepcopy(MQL)

   for i in range(nreplay):     
      rl = np.random.randint(s_batch.shape[0], size=1)[0]
      prev_state_dec    = int(s_batch[rl])
      next_action_dec   = int(a_batch[rl])
      next_state_dec    = int(sn_batch[rl])
      next_MQLmax       = np.max(MQLC[next_state_dec,:])
      next_MQLmax_inv   = np.max(MQL[prev_state_dec,:])
      current_MQLval    = MQLC[prev_state_dec,next_action_dec]
      current_MQLval_inv= MQLC[prev_state_dec,next_action_dec]
      current_reward    = r_batch[rl]
      
      MQLC[prev_state_dec,next_action_dec] = (1-alpha)*current_MQLval + \
         alpha*(current_reward + gamma*next_MQLmax)

      MQLC[next_state_dec,next_action_dec] = (1-alpha)*current_MQLval_inv + \
         alpha*(-current_reward + gamma*next_MQLmax_inv)
         
      DMQL.append(DMQL.append(np.linalg.norm(MQLC-MQLn))) #np.max(MQLC-MQLn)
      MQLn = copy.deepcopy(MQLC)
   
   return MQLC, DMQL  

def find_gait_sb(state_dec, MQL):
  
  vel = 0.0
  slist = []
  alist = []
  current_state_dec = state_dec
  Deltas = ReadDeltasTables(ndeltas, nstates, nactions, DELTAS)
  
  for j in range(1000):
    action = np.zeros(nlinks, dtype=int)
    aux_current = np.array([int(i) for i in np.binary_repr(current_state_dec,width=nlinks)])
    action[np.argmax(MQL[current_state_dec,:])] = 1
    action_dec = np.dot(action,2**np.arange(nlinks-1,-1,-1,dtype=int)) 
    aux_state = np.remainder(aux_current+action,2*np.ones(nlinks, dtype=int))    
    next_state_dec = np.dot(aux_state,2**np.arange(nlinks-1,-1,-1,dtype=int))    
    
    if(j>99):
        if rcase == 1:
            vel += (Deltas[2][current_state_dec, action.argmax()] - Deltas[2][next_state_dec, action.argmax()])/2
        elif rcase == 2:
            vel += (Deltas[0][current_state_dec, action.argmax()] - Deltas[0][next_state_dec, action.argmax()])/2   
    
    slist.append(current_state_dec)
    alist.append(action_dec)
    
    current_state_dec = next_state_dec 
  
  vel = vel/900
  return slist[990:1000], alist[990:1000],vel 

def find_gait(state_dec, MQL):
  
  vel = 0.0
  slist = []
  alist = []
  seqrep = []
  current_state_dec = state_dec
  Deltas = ReadDeltasTables(ndeltas, nstates, nactions, DELTAS)
  
  for j in range(30):
    action = np.zeros(nlinks, dtype=int)
    aux_current = np.array([int(i) for i in np.binary_repr(current_state_dec,width=nlinks)])
    action[np.argmax(MQL[current_state_dec,:])] = 1
    action_dec = np.dot(action,2**np.arange(nlinks-1,-1,-1,dtype=int)) 
    aux_state = np.remainder(aux_current+action,2*np.ones(nlinks, dtype=int))    
    next_state_dec = np.dot(aux_state,2**np.arange(nlinks-1,-1,-1,dtype=int))     
    
    slist.append(current_state_dec)
    alist.append(action_dec)
    
    current_state_dec = next_state_dec 
  
  for tam in range(2,int(len(slist)/2)+1):
      
      for i in range(len(slist)-(tam-1)):
          seq = slist[i:tam+i]                
          count=0
          for j in range(len(slist)-(tam-1)):
              seqcomp = slist[j:tam+j]           
              if(seq == seqcomp):              
                count+=1

              if(count>1):              
                flagnum = 0
                for k in range(len(seq)):                                    
                    flag=0
                    for l in range(len(seq)):                      
                        if(seq[k] == seq[l]):
                            flag+=1

                        if(flag == 2):
                            flagnum = 1

                if(flagnum == 0):
                    seqrep = seq            
    
  for i in range(len(seqrep)):
      current_state_dec = seqrep[i]
      action = np.argmax(MQL[current_state_dec,:])
      if(i == len(seqrep)-1):
          next_state_dec = seqrep[0]
      else:         
          next_state_dec = seqrep[i+1]
            
      vel += (Deltas[2][current_state_dec, action] - Deltas[2][next_state_dec, action])/2
      

  if(len(seqrep) == 0):
      vel = 0.0
  else:
      vel = vel/len(seqrep)

  return slist, alist,vel,seqrep

# %%
gammalist = [0.999,0.99,0.988,0.95,0.9,0.7,0.1]
alphalist = [1.0,0.5,0.1]

nreplay = 100
replay_step = -100

for alpha in alphalist:
  for gamma in gammalist:
    MQL, DMQL = QL_steps_sb(s_batch,sn_batch,a_batch,r_batch,alpha,gamma,replay_step,nreplay)

    prev_state_dec  = int(s_batch[0])    
    FDMQL = scipy.signal.savgol_filter(DMQL,15,0)    
    ##slist, alist, vel = find_gait_sb(prev_state_dec, MQL)
    ##print(f'alpha = {alpha}, gamma = {gamma:.3f}, dQ = {FDMQL[-1]:e}, {slist}, vel = {vel:.5f}')
    slist, alist, vel,seqrep = find_gait(prev_state_dec, MQL)
    print(f'alpha = {alpha}, gamma = {gamma:.3f}, dQ = {FDMQL[-1]:e}, {seqrep} ,vel = {vel:.5f}')
# Out:
# alpha = 1.0, gamma = 0.999, dQ = 1.202754e-04, [5, 1, 0, 4] ,vel = 0.00839
# alpha = 1.0, gamma = 0.990, dQ = 1.224377e-04, [5, 1, 0, 4] ,vel = 0.00839
# alpha = 1.0, gamma = 0.988, dQ = 1.220802e-04, [5, 1, 0, 4] ,vel = 0.00839
# alpha = 1.0, gamma = 0.950, dQ = 1.562763e-04, [0, 1] ,vel = 0.00000
# alpha = 1.0, gamma = 0.900, dQ = 1.076646e-04, [0, 1] ,vel = 0.00000
# alpha = 1.0, gamma = 0.700, dQ = 9.849113e-05, [0, 1] ,vel = 0.00000
# alpha = 1.0, gamma = 0.100, dQ = 7.473297e-05, [0, 1] ,vel = 0.00000
# alpha = 0.5, gamma = 0.999, dQ = 2.837455e-01, [6, 4] ,vel = 0.00000
# alpha = 0.5, gamma = 0.990, dQ = 2.856054e-01, [6, 4] ,vel = 0.00000
# alpha = 0.5, gamma = 0.988, dQ = 2.856834e-01, [6, 4] ,vel = 0.00000
# alpha = 0.5, gamma = 0.950, dQ = 2.865995e-01, [0, 4] ,vel = 0.00000
# alpha = 0.5, gamma = 0.900, dQ = 2.886573e-01, [0, 4] ,vel = 0.00000
# alpha = 0.5, gamma = 0.700, dQ = 3.148418e-01, [0, 1] ,vel = 0.00000
# ...
